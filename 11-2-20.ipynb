# %%
import pandas as pd

# %%
bird=pd.read_csv('bird data.csv')

# %%
bird
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ..   ...
# 415   SO
# 416   SO
# 417   SO
# 418   SO
# 419   SO
#
# [420 rows x 12 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(bird,hue='type')

# %%
bird.isnull().sum()
# Out:
# id       0
# huml     1
# humw     1
# ulnal    3
# ulnaw    2
# feml     2
# femw     1
# tibl     2
# tibw     1
# tarl     1
# tarw     1
# type     0
# dtype: int64

# %%
bird.dropna(inplace=True)

# %%
bird.duplicated().sum()
# Out:
# 0

# %%
bird.drop_duplicates()
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ..   ...
# 415   SO
# 416   SO
# 417   SO
# 418   SO
# 419   SO
#
# [413 rows x 12 columns]

# %%
bird.drop_duplicates()
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ..   ...
# 415   SO
# 416   SO
# 417   SO
# 418   SO
# 419   SO
#
# [413 rows x 12 columns]

# %%
bird['type'].value_counts()
# Out:
# SO    124
# SW    116
# W      64
# R      48
# P      38
# T      23
# Name: type, dtype: int64

# %%
y=bird['type']
x=bird.drop('type',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
y_pred=tree.predict(x_test)

# %%
y_pred
# Out:
# array(['SO', 'SO', 'SO', 'SO', 'T', 'SO', 'SO', 'R', 'SO', 'T', 'SO',
#        'SW', 'SW', 'SW', 'W', 'W', 'SW', 'P', 'W', 'SO', 'SW', 'SW', 'SO',
#        'SO', 'SO', 'SO', 'SW', 'SO', 'SW', 'W', 'SW', 'W', 'W', 'SW',
#        'SW', 'SO', 'P', 'P', 'P', 'SO', 'SW', 'SO', 'SW', 'W', 'P', 'T',
#        'SO', 'SO', 'SW', 'SO', 'R', 'SW', 'P', 'SO', 'SW', 'SW', 'SW',
#        'SO', 'SW', 'SW', 'SO', 'SW', 'SO', 'SO', 'SW', 'SW', 'SW', 'SW',
#        'SW', 'W', 'W', 'SW', 'SO', 'SW', 'SW', 'T', 'P', 'SW', 'P', 'SO',
#        'T', 'P', 'SO', 'R', 'SW', 'SW', 'SW', 'P', 'SO', 'SO', 'P', 'SO',
#        'SW', 'SW', 'R', 'SW', 'SO', 'SO', 'SW', 'SO', 'R', 'W', 'W', 'SO',
#        'SO', 'SO', 'W', 'W', 'P', 'SW', 'SW', 'T', 'SW', 'P', 'SO', 'P',
#        'W', 'R', 'SW', 'SO', 'T', 'SW', 'SW', 'W', 'SW', 'T', 'SW', 'W',
#        'SO', 'SO', 'SO', 'T', 'W', 'SW', 'SO', 'T', 'W', 'W', 'SW', 'SO',
#        'W', 'SW', 'P', 'W', 'R', 'R', 'W', 'W', 'SO', 'SO', 'SW', 'W',
#        'SO', 'SO', 'R', 'R', 'SW', 'SW', 'W', 'SO', 'SW', 'SO', 'P', 'W',
#        'W', 'SW', 'R', 'SW', 'SW', 'R', 'SO', 'W', 'SO', 'R', 'R', 'W',
#        'P', 'SW', 'SO', 'W', 'W', 'R', 'SW', 'SW', 'W', 'SW', 'W', 'SO',
#        'SW', 'P', 'SW', 'SW', 'SW', 'W', 'W', 'SO', 'T', 'SW', 'SO', 'SO',
#        'R', 'R', 'SO', 'R', 'W', 'W', 'P', 'SW', 'SO', 'R', 'SO', 'R',
#        'P', 'SO', 'T', 'P', 'SO', 'R', 'SO', 'W', 'SW', 'SW', 'SO', 'T',
#        'R', 'SW', 'W', 'SO', 'P', 'SO', 'W', 'SO', 'P', 'SO', 'SO', 'R',
#        'SO', 'SO', 'W', 'P', 'W', 'W', 'T', 'T', 'SO', 'SW', 'R', 'R',
#        'W', 'SO', 'P', 'SW', 'W', 'SO', 'R', 'SO', 'SO', 'W', 'SO', 'SW',
#        'SO', 'W', 'SO', 'SW', 'SO', 'SW', 'SW', 'R', 'T', 'W', 'SW', 'SW',
#        'SW', 'W', 'W', 'SO', 'P', 'R', 'SW', 'SW', 'R', 'SO', 'SO', 'W',
#        'SW', 'SO', 'R', 'P', 'P', 'SO'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
con=confusion_matrix(y_pred,y_test)
con
# Out:
# array([[23,  3,  2,  0,  0,  0],
#        [ 0, 30,  0,  0,  0,  0],
#        [ 0,  0, 85,  0,  0,  0],
#        [ 0,  0,  0, 80,  0,  0],
#        [ 0,  1,  0,  0, 15,  0],
#        [ 0,  0,  0,  2,  1, 48]], dtype=int64)

# %%
import os
os.environ['path']+=os.environ['path']+';'
